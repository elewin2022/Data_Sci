# %% [markdown]
# <a href="https://colab.research.google.com/github/elewin2022/Data_Sci/blob/main/_111_Copy_of_Ethan_Lewin_2ndtry_(Final)_Copy_of_Hahn_Stats_Midterm_Linear_Regression_(real_one).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STA 2023 Midterm Project
#
# Directions:
#
# *   Use any and all resources available to you
# *   Comment and explain the code
# *   Answer the questions to the best of your abilities
# *   There are no points for pain: ask for help
#
# Save this notebook to your GitHub and submit the link.

# %%
import numpy as np #import databases numpy and matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Getting your data
#
# Create a google form to input your data.
# Follow the same method as [Lab 5](https://colab.research.google.com/drive/1zYvyhrz2wVnJXlZqj_PpxOxplfS3LN9Y?usp=sharing).

# %%
import pandas as pd #importing another library database
def get_database(url): # This function loads the google spreadsheet
    url_head = "https://docs.google.com/spreadsheets/d/" #this is the first part of the link to the spreadsheet
    url_foot = "/gviz/tq?tqx=out:csv&sheet="
    url_body = url.split('/')[5]
    sheet_name = "1"
    url_csv = url_head + url_body + url_foot + sheet_name
    df = pd.read_csv(url_csv, sep=',', skiprows=0)
    return df

# %% [markdown]
# Put your form url here:

# %%
url = 'https://docs.google.com/spreadsheets/d/1MzkvoAQ7WLzOfAW8AYRdZSnqeyl4luzkmXO87wut-bs/edit?usp=sharing' #importing the url link to the shared spreadsheet with data about circles

# %%
url #testing that link works
# Out:
# 'https://docs.google.com/spreadsheets/d/1MzkvoAQ7WLzOfAW8AYRdZSnqeyl4luzkmXO87wut-bs/edit?usp=sharing'

# %%
data = get_database(url) #pulling the data from the spreedsheet to collab

# %%
data #data table of circles from spreadsheet, put the data in as an array
# Out:
#         Object Diameter Circumference
# 0         Lime   1.5 in         4.7 in
# 1  Tennis ball  2.5 in          7.9 in
# 2   Scuba Tank  7.25 in        22.8 in
# 3        Pizza    12 in        37.7 in
# 4        Clock    18 in        56.5 in

# %%
D = np.array ([1.5, 2.5, 7.25, 12, 18]) #setting the range of values for the diameters of different circles and then the circumferences of different circles
C = np.array ([4.7, 7.9, 22.8,37.7, 56.6])

# %%
plt.plot(D,C, 'g.') #plotting the diamter and circumference data

# %%
m_guess = 0
b_guess = 0

# %%
X = D #setting x equal to diameter values
Y = C #setting y equal to circumference values

# %%
X #reprinting x to test if the data range values of diameters was imported correctly. It works
# Out:
# array([ 1.5 ,  2.5 ,  7.25, 12.  , 18.  ])

# %% [markdown]
# $y=mx+b$

# %%
m_guess * X + b_guess
# Out:
# array([0., 0., 0., 0., 0.])

# %%
y_guess = m_guess * X + b_guess #we have some data that we have brought in, we are trying to fit a linear model, for every number given in list of x multiple by m and add b

# %% [markdown]
# Plot your data points

# %%
Y #reprinting y to test if the data range values of circumferences was imported correctly. It works
# Out:
# array([ 4.7,  7.9, 22.8, 37.7, 56.6])

# %%
y_guess
# Out:
# array([0., 0., 0., 0., 0.])

# %%
y_guess - Y #we do not want negatives to cancel out #this minus sign (-) is the distance from dots to line (cancel out), to make sure they come out as a positive number, we square it, we want the LEAST square (least square fitting), find value that will give us the least squares
# Out:
# array([ -4.7,  -7.9, -22.8, -37.7, -56.6])

# %%
np.sum((y_guess - Y)**2) #turns negative numbers into positive numbers, way to mathematically get rid of minus signs #taken data, created model, multiplied by m and added b every time, call this new list y_guess and find out if the line accurately fits data
# Out:
# 5229.1900000000005

# %%
loss = np.sum((y_guess - Y)**2)

# %%
best_loss_so_far = 10000000000000000
m_best = 0
b_best= 0

for m_guess in np.linspace (-100,100,100): #print out all possible guesses for m
    for b_guess in np.linspace(-100,100,100):

        y_guess = m_guess * X + b_guess #linear regression

        loss = np.sum((y_guess - Y)**2)

        if loss < best_loss_so_far:  #update best loss so far to keep track that we found a better one
            m_best = m_guess
            b_best = b_guess
            best_loss_so_far = loss
print("Found better fit:") #shifttab to move it back 
print(m_best,b_best,loss) #3 represents slope of the line of best fit, change of y/change of x, relates diameter of circle to circumference of circle, IT'S PIE, there is a special number inside of every circle and it tells you special relationship between diameter and circumference
# Out:
# Found better fit:
# 3.030303030303031 1.0101010101010104 5812254.19

# %%
plt.title("Circle Diameter vs Circumference") #labeling the title, x and y labels for the graph, and then plotting the data points of diameters and circumferences to make the graph

plt.xlabel("Diameter") #point of model is to be able to make a new prediction, won't even have to measure circumference, will be able to predict very accurately using linear relationship, using y=mx+b model
plt.ylabel("Circumference")

plt.plot(D,C, '.');

# %% [markdown]
# ## Part 2: Linear Fit
#
# Follow the steps in the [Linear Fit notebook]() to run a linear fit on your data.

# %%
best_loss = 1000000000 #this block of code allows us to determine where the best bit of the line will land, the amount of error from linear line to data points
best_m = 0 #going to create a model of a straight line to make a guess about some data we do not have
best_b = 0 

for m_guess in np.linspace(-100,100,100): #assume slope is not less than slope is -100 and 100 in 100 steps
    for b_guess in np.linspace(-100,100,100): #for the first value of m, try all values of b again

        print("Now Testing: ", m_guess, b_guess)
        
        y_guess = m_guess * X + b_guess

        loss = np.sum((y_guess - Y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess
# Out:
# Streaming output truncated to the last 5000 lines.
# Now Testing:  1.0101010101010104 -100.0
# Now Testing:  1.0101010101010104 -97.97979797979798
# Now Testing:  1.0101010101010104 -95.95959595959596
# Now Testing:  1.0101010101010104 -93.93939393939394
# Now Testing:  1.0101010101010104 -91.91919191919192
# Now Testing:  1.0101010101010104 -89.8989898989899
# Now Testing:  1.0101010101010104 -87.87878787878788
# Now Testing:  1.0101010101010104 -85.85858585858585
# Now Testing:  1.0101010101010104 -83.83838383838383
# Now Testing:  1.0101010101010104 -81.81818181818181
# Now Testing:  1.0101010101010104 -79.79797979797979
# Now Testing:  1.0101010101010104 -77.77777777777777
# Now Testing:  1.0101010101010104 -75.75757575757575
# Now Testing:  1.0101010101010104 -73.73737373737373
# Now Testing:  1.0101010101010104 -71.71717171717171
# Now Testing:  1.0101010101010104 -69.69696969696969
# Now Testing:  1.0101010101010104 -67.67676767676767
# ...

# %%
y_guess = best_m * x + best_b #plotting the graph and then using the function to guess the best line #having our model predict new data

plt.plot(x,y_guess,'r');
plt.plot(D,C,'g.'); 
plt.show()

print(best_loss,best_m,best_b)
# Out:
# 2.432016120803972 3.030303030303031 1.0101010101010104

# %% [markdown]
# Plot the line of best fit:
#
# Use blue dots for the collected data and a red line for the estimate.

# %%
plt.title('Linear Fit of Circles') #adding a title to the graph, labels, then plotting the graph, and creating a legend 

plt.xlabel('Diameter')
plt.ylabel('Circumference')

# Plot the collected data
plt.plot(D,C,'b.', label='Observations')

y_estimate = 3.030303030303031

# Plot the line of best fit
plt.plot(D,C,'r', label=f'Estimate: $y = {3.030303030303031} x + {0}$')

plt.legend();

# %% [markdown]
# The estimated relationship is:
#
# $C = ? D + ?$

# %%
#Circumference = πDiameter

# %% [markdown]
# ## Part 3: Interpretation
#
# Answer the questions in text cells

# %% [markdown]
# #### Question 1:
#
# What do $m$ and $b$ represent in these equations?

# %% [markdown]
# m represents the slope and b represents the y-intercept.

# %% [markdown]
# #### Question 2:
#
# Guess what the correct values $m$ and $b$ should be.

# %% [markdown]
# m is pie, and b should be zero

# %% [markdown]
# #### Question 3:
#
# Does it make sense to include $b$ in the parameters?

# %% [markdown]
# No, cause it didn't exist. As we expect diameter to go to zero the circumference would also be zero

# %% [markdown]
# ## Bonus:
#
# These problems are extra credit. You may use any resources, but be sure to explain your code.

# %% [markdown]
# #### Bonus 1: Plot the squared errors from your line of best fit

# %%
plt.title("Fit Errors")

plt.xlabel("Diameter")
plt.ylabel("Squared Error")

squared_error = ...

plt.plot(..., 'b.', label = "Errors")

plt.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-77c7485c31ce> in <module>
#       6 squared_error = ...
#       7
# ----> 8 plt.plot(..., 'b.', label = "Errors")
#       9
#      10 plt.legend();
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# -> 1649             self.add_line(line)
#    1650         self._request_autoscale_view(scalex=scalex, scaley=scaley)
# ...

# %% [markdown]
# #### Bonus 2: Plot the errors as a histogram

# %%
plt.title("Errors")

...

# %% [markdown]
# What distribution does this histogram look like?

# %% [markdown]
# #### Bonus 3: Find the circle with the largest error.
# Hint: use np.max

# %%
largest_error = ...

# %% [markdown]
# #### Bonus 4: Remove the circles with the 2 largest errors and run the fit again.

# %%
...

# %% [markdown]
# What is the difference in your error?

# %% [markdown]
# #### Bonus 5: Find and explain a better method of fitting this data
